# %%
import pandas as pd
df = pd.read_csv("/Users/macbook/Downloads/2022-11-21_-_Worker_and_Temporary_Worker.csv", index_col=0)

# %%
df
# Out:
#                                                           Town/City  \
# Organisation Name
# (Arbuthnott Community Association) Lewis Grassi...     Laurencekirk
# (Arbuthnott Community Association) Lewis Grassi...     Laurencekirk
# @ Architect UK Ltd                                     West Horndon
# @ Home Accommodation Services Ltd                            London
# @ Home Accommodation Services Ltd                            London
# ...                                                             ...
# Zytronic Displays Limited                           Blaydon on Tyne
# ZyXEL Communications UK Ltd                               Wokingham
# ZyXEL Communications UK Ltd                               Wokingham
# ZZA CONSULTING LIMITED                                       LONDON
# Zzoomm Plc                                                   Oxford
#
#                                                            County  \
# Organisation Name
# ...

# %%
a = df["Town/City"].unique()
for i in a:
    if i == 'Southampton':
        print(i)
# Out:
# Southampton

# %%
b = df.loc[df['Town/City'] == "Southampton"]

# %%
b
# Out:
#                                        Town/City     County  \
# Organisation Name
# 7Bone Holdings Limited               Southampton        NaN
# A&F PRIME CARE LTD                   Southampton  Hampshire
# Above Bar Church                     Southampton  Hampshire
# Above Bar Church                     Southampton  Hampshire
# Absolar Solutions Limited            Southampton        NaN
# ...                                          ...        ...
# X-Press Container Line (UK) Limited  Southampton        NaN
# X-Press Container Line (UK) Limited  Southampton        NaN
# Yau Brothers & Company Limited       Southampton        NaN
# YMCA Fairthorne Group                Southampton  Hampshire
# YMCA Fairthorne Group                Southampton  Hampshire
#
#                                                    Type & Rating  \
# Organisation Name
# 7Bone Holdings Limited                         Worker (A rating)
# A&F PRIME CARE LTD                             Worker (A rating)
# ...

# %%
c = b["Type & Rating"].unique()
c
# Out:
# array(['Worker (A rating)', 'Temporary Worker (A rating)',
#        'Worker (A (Premium))', 'Worker (A (SME+))',
#        'Temporary Worker (A (SME+))'], dtype=object)

# %%
d = b.loc[b['Type & Rating'] == "Worker (A rating)"]

# %%
d
# Out:
#                                        Town/City     County  \
# Organisation Name
# 7Bone Holdings Limited               Southampton        NaN
# A&F PRIME CARE LTD                   Southampton  Hampshire
# Absolar Solutions Limited            Southampton        NaN
# Accelercomm Limited                  Southampton  Hampshire
# Alliants Limited                     Southampton  Hampshire
# ...                                          ...        ...
# Xim Limited                          Southampton        NaN
# X-Press Container Line (UK) Limited  Southampton        NaN
# X-Press Container Line (UK) Limited  Southampton        NaN
# Yau Brothers & Company Limited       Southampton        NaN
# YMCA Fairthorne Group                Southampton  Hampshire
#
#                                          Type & Rating  \
# Organisation Name
# 7Bone Holdings Limited               Worker (A rating)
# A&F PRIME CARE LTD                   Worker (A rating)
# ...

# %%
e = d.loc[d['Route'] == "Skilled Worker"]
pd.set_option('display.max_rows', None)

e
# Out:
#                                                       Town/City     County  \
# Organisation Name
# 7Bone Holdings Limited                              Southampton        NaN
# A&F PRIME CARE LTD                                  Southampton  Hampshire
# Absolar Solutions Limited                           Southampton        NaN
# Accelercomm Limited                                 Southampton  Hampshire
# Alliants Limited                                    Southampton  Hampshire
# Al-Nafay Uk Limited                                 Southampton        NaN
# Anderselite                                         Southampton        NaN
# Argo Engineering Solutions Ltd                      Southampton  Hampshire
# Arrow Convenience Limited                           Southampton        NaN
# Ascend Technologies Limited                         Southampton  Hampshire
# Asia Pacific World Holdings Limited                 Southampton        NaN
# ...

# %%
e['Organisation Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:3080, in Index.get_loc(self, key, method, tolerance)
#    3079 try:
# -> 3080     return self._engine.get_loc(casted_key)
#    3081 except KeyError as err:
#
# File pandas/_libs/index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:4554, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:4562, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Organisation Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ...

# %%
# Out:
# Town/City
# County
# Type & Rating
# Route
